# %% [markdown]
# # Regressão Softmax com dados do MNIST utilizando gradiente descendente estocástico por minibatches

# %% [markdown]
# O objetivo deste notebook é ilustrar
# - o uso do gradiente estocástico por mini-batchs
# - utilizando as classes Dataset e DataLoater.
#
# A apresentação da perda nos gráficos é um pouco diferente da usual, mostrando a perda de cada um dos vários minibatches dentro de cada época, de forma que as épocas são apresentadas com valores fracionários.

# %% [markdown]
# ## Importação das bibliotecas

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader

import torchvision
from torchvision.datasets import MNIST

# %% [markdown]
# ## Dataset e dataloader

# %% [markdown]
# ### Definição do tamanho do minibatch

# %%
batch_size = 100

# %% [markdown]
# ### Carregamento, criação dataset e do dataloader

# %%
dataset_dir = 'MNIST/'

# Load the full MNIST training dataset
full_train_dataset = MNIST(dataset_dir, train=True, download=True,
                      transform=torchvision.transforms.ToTensor())

# Define the split ratio (e.g., 80% for training, 20% for validation)
train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

# Split the dataset
dataset_train, dataset_val = torch.utils.data.random_split(full_train_dataset, [train_size, val_size])

# Create DataLoaders for training and validation
loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
loader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False) # No need to shuffle validation data

print(f'Número total de amostras de treinamento original: {len(full_train_dataset)}')
print(f'Número de amostras de treinamento: {len(dataset_train)}')
print(f'Número de amostras de validação: {len(dataset_val)}')
print('Número de minibatches de treinamento:', len(loader_train))
print('Número de minibatches de validação:', len(loader_val))

x_train_sample, y_train_sample = next(iter(loader_train))
print("\nDimensões dos dados de um minibatch de treinamento:", x_train_sample.size())
print("Valores mínimo e máximo dos pixels: ", torch.min(x_train_sample), torch.max(x_train_sample))
print("Tipo dos dados das imagens:         ", type(x_train_sample))
print("Tipo das classes das imagens:       ", type(y_train_sample))
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.49MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 130kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.22MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 12.9MB/s]
# Número total de amostras de treinamento original: 60000
# Número de amostras de treinamento: 48000
# Número de amostras de validação: 12000
# Número de minibatches de treinamento: 480
# Número de minibatches de validação: 120
#
# Dimensões dos dados de um minibatch de treinamento: torch.Size([100, 1, 28, 28])
# Valores mínimo e máximo dos pixels:  tensor(0.) tensor(1.)
# Tipo dos dados das imagens:          <class 'torch.Tensor'>
# Tipo das classes das imagens:        <class 'torch.Tensor'>

# %% [markdown]
# ### Usando todas as amostras do MNIST
#
# Neste exemplo utilizaremos todas as amostras de treinamento.

# %%
# The original `total_samples` was for the full training set. Now we have a split.
n_batches_train = len(loader_train)
n_batches_val = len(loader_val)
total_train_samples = len(dataset_train)
total_val_samples = len(dataset_val)

print(f'Número de minibatches de treinamento: {n_batches_train}')
print(f'Número de minibatches de validação: {n_batches_val}')
print(f'Total de amostras de treinamento: {total_train_samples}')
print(f'Total de amostras de validação: {total_val_samples}')
# Out:
# Número de minibatches de treinamento: 480
# Número de minibatches de validação: 120
# Total de amostras de treinamento: 48000
# Total de amostras de validação: 12000

# %% [markdown]
# ## Modelo

# %%
model = torch.nn.Linear(28*28, 10)

# %%
x = torch.ones(28*28).reshape(1, 784)
print(x.shape)
predict = model(x)
predict
# Out:
# torch.Size([1, 784])
# tensor([[ 0.0617,  0.4240,  0.2361, -0.2950, -0.2929, -0.1072, -0.0275, -0.7930,
#          -0.3465,  0.3306]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Treinamento
#
# Durante o treinamento, acompanharemos a perda e a acurácia para os conjuntos de treinamento e validação em cada época.

# %% [markdown]
# ### Inicialização dos parâmetros

# %%
n_epochs = 5
learningRate = 0.5

# Utilizaremos CrossEntropyLoss como função de perda
criterion = torch.nn.CrossEntropyLoss()

# Gradiente descendente
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

# %% [markdown]
# ### Laço de treinamento dos parâmetros

# %%
train_losses_per_epoch = []
val_losses_per_epoch = []
train_accuracies_per_epoch = []
val_accuracies_per_epoch = []

for epoch in range(n_epochs):
    # Training phase
    model.train() # Set model to training mode
    correct_train = 0
    total_train = 0
    running_train_loss = 0.0

    for i, (x_train, y_train) in enumerate(loader_train):
        inputs = Variable(x_train.view(-1, 28 * 28))
        labels = Variable(y_train)

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    avg_train_loss = running_train_loss / len(loader_train)
    train_accuracy = correct_train / total_train
    train_losses_per_epoch.append(avg_train_loss)
    train_accuracies_per_epoch.append(train_accuracy)

    # Validation phase
    model.eval() # Set model to evaluation mode
    correct_val = 0
    total_val = 0
    running_val_loss = 0.0

    with torch.no_grad(): # Disable gradient calculations during validation
        for x_val, y_val in loader_val:
            inputs_val = Variable(x_val.view(-1, 28 * 28))
            labels_val = Variable(y_val)

            outputs_val = model(inputs_val)
            loss_val = criterion(outputs_val, labels_val)

            running_val_loss += loss_val.item()
            _, predicted_val = torch.max(outputs_val.data, 1)
            total_val += labels_val.size(0)
            correct_val += (predicted_val == labels_val).sum().item()

    avg_val_loss = running_val_loss / len(loader_val)
    val_accuracy = correct_val / total_val
    val_losses_per_epoch.append(avg_val_loss)
    val_accuracies_per_epoch.append(val_accuracy)

    print(f'Epoch [{epoch+1}/{n_epochs}], ' \
          f'Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}, ' \
          f'Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}')
# Out:
# Epoch [1/5], Train Loss: 0.4081, Train Acc: 0.8841, Val Loss: 0.3416, Val Acc: 0.9005
# Epoch [2/5], Train Loss: 0.3101, Train Acc: 0.9124, Val Loss: 0.3206, Val Acc: 0.9105
# Epoch [3/5], Train Loss: 0.2936, Train Acc: 0.9173, Val Loss: 0.3160, Val Acc: 0.9126
# Epoch [4/5], Train Loss: 0.2845, Train Acc: 0.9204, Val Loss: 0.3052, Val Acc: 0.9139
# Epoch [5/5], Train Loss: 0.2783, Train Acc: 0.9225, Val Loss: 0.3007, Val Acc: 0.9139

# %%
print('--- Treinamento Finalizado ---')
print(f'Última perda de treinamento: {train_losses_per_epoch[-1]:.4f}')
print(f'Última acurácia de treinamento: {train_accuracies_per_epoch[-1]:.4f}')
print(f'Última perda de validação: {val_losses_per_epoch[-1]:.4f}')
print(f'Última acurácia de validação: {val_accuracies_per_epoch[-1]:.4f}')
# Out:
# --- Treinamento Finalizado ---
# Última perda de treinamento: 0.2783
# Última acurácia de treinamento: 0.9225
# Última perda de validação: 0.3007
# Última acurácia de validação: 0.9139

# %% [markdown]
# ### Visualizando a evolução da perda e acurácia

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, n_epochs + 1), train_losses_per_epoch, label='Perda de Treinamento')
plt.plot(range(1, n_epochs + 1), val_losses_per_epoch, label='Perda de Validação')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.title('Evolução da Perda (Treinamento vs. Validação)')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(1, n_epochs + 1), train_accuracies_per_epoch, label='Acurácia de Treinamento')
plt.plot(range(1, n_epochs + 1), val_accuracies_per_epoch, label='Acurácia de Validação')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.title('Evolução da Acurácia (Treinamento vs. Validação)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observações sobre os gráficos
#
# Estes gráficos mostram a perda e a acurácia calculadas ao final de cada época para os conjuntos de treinamento e validação. Idealmente, a perda de treinamento e validação deve diminuir, e a acurácia deve aumentar, com as curvas de validação seguindo de perto as de treinamento. Divergências significativas podem indicar overfitting ou underfitting.

# %% [markdown]
# # Atividades

# %% [markdown]
# ## Perguntas

# %% [markdown]
# 1. Qual é o tamanho do mini-batch? 100 amostras
# 2. Em uma época, quantos mini-batches existem? 480 batches por epoca
# 3. Qual é a definição de época?  è quando o modelo passou por todas as samostras do dataset de treinamento uma vez.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Coloque um print no final de cada minibatch, no mesmo estilo do print do final de época, no seguinte estilo:
#     - Época: 1/4, batch: 600
# 2. Altere o tamanho de minibatch (batch_size) algumas vezes, refaça o treinamento, e compare no gráfico abaixo a queda da perda para cada tamanho de minibatch.

# %%
train_losses_per_epoch = []
val_losses_per_epoch = []
train_accuracies_per_epoch = []
val_accuracies_per_epoch = []

for epoch in range(n_epochs):
    # Training phase
    model.train()
    correct_train = 0
    total_train = 0
    running_train_loss = 0.0

    for i, (x_train, y_train) in enumerate(loader_train):
        inputs = Variable(x_train.view(-1, 28 * 28))
        labels = Variable(y_train)

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        print(f'Época: {epoch+1}/{n_epochs}, batch: {(i+1)*batch_size}')

    avg_train_loss = running_train_loss / len(loader_train)
    train_accuracy = correct_train / total_train
    train_losses_per_epoch.append(avg_train_loss)
    train_accuracies_per_epoch.append(train_accuracy)

    # Validation phase
    model.eval()
    correct_val = 0
    total_val = 0
    running_val_loss = 0.0

    with torch.no_grad():
        for x_val, y_val in loader_val:
            inputs_val = Variable(x_val.view(-1, 28 * 28))
            labels_val = Variable(y_val)

            outputs_val = model(inputs_val)
            loss_val = criterion(outputs_val, labels_val)

            running_val_loss += loss_val.item()
            _, predicted_val = torch.max(outputs_val.data, 1)
            total_val += labels_val.size(0)
            correct_val += (predicted_val == labels_val).sum().item()

    avg_val_loss = running_val_loss / len(loader_val)
    val_accuracy = correct_val / total_val
    val_losses_per_epoch.append(avg_val_loss)
    val_accuracies_per_epoch.append(val_accuracy)
    print(f'Epoch [{epoch+1}/{n_epochs}], Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}')
# Out:
# Época: 1/5, batch: 512
# Época: 1/5, batch: 1024
# Época: 1/5, batch: 1536
# Época: 1/5, batch: 2048
# Época: 1/5, batch: 2560
# Época: 1/5, batch: 3072
# Época: 1/5, batch: 3584
# Época: 1/5, batch: 4096
# Época: 1/5, batch: 4608
# Época: 1/5, batch: 5120
# Época: 1/5, batch: 5632
# Época: 1/5, batch: 6144
# Época: 1/5, batch: 6656
# Época: 1/5, batch: 7168
# Época: 1/5, batch: 7680
# Época: 1/5, batch: 8192
# Época: 1/5, batch: 8704
# Época: 1/5, batch: 9216
# Época: 1/5, batch: 9728
# Época: 1/5, batch: 10240
# Época: 1/5, batch: 10752
# Época: 1/5, batch: 11264
# Época: 1/5, batch: 11776
# Época: 1/5, batch: 12288
# Época: 1/5, batch: 12800
# Época: 1/5, batch: 13312
# Época: 1/5, batch: 13824
# Época: 1/5, batch: 14336
# Época: 1/5, batch: 14848
# Época: 1/5, batch: 15360
# Época: 1/5, batch: 15872
# Época: 1/5, batch: 16384
# Época: 1/5, batch: 16896
# Época: 1/5, batch: 17408
# Época: 1/5, batch: 17920
# Época: 1/5, batch: 18432
# Época: 1/5, batch: 18944
# Época: 1/5, batch: 19456
# Época: 1/5, batch: 19968
# Época: 1/5, batch: 20480
# Época: 1/5, batch: 20992
# Época: 1/5, batch: 21504
# Época: 1/5, batch: 22016
# Época: 1/5, batch: 22528
# Época: 1/5, batch: 23040
# Época: 1/5, batch: 23552
# Época: 1/5, batch: 24064
# Época: 1/5, batch: 24576
# Época: 1/5, batch: 25088
# Época: 1/5, batch: 25600
# Época: 1/5, batch: 26112
# Época: 1/5, batch: 26624
# Época: 1/5, batch: 27136
# Época: 1/5, batch: 27648
# Época: 1/5, batch: 28160
# Época: 1/5, batch: 28672
# Época: 1/5, batch: 29184
# Época: 1/5, batch: 29696
# Época: 1/5, batch: 30208
# Época: 1/5, batch: 30720
# Época: 1/5, batch: 31232
# Época: 1/5, batch: 31744
# Época: 1/5, batch: 32256
# Época: 1/5, batch: 32768
# Época: 1/5, batch: 33280
# Época: 1/5, batch: 33792
# Época: 1/5, batch: 34304
# Época: 1/5, batch: 34816
# Época: 1/5, batch: 35328
# Época: 1/5, batch: 35840
# Época: 1/5, batch: 36352
# Época: 1/5, batch: 36864
# Época: 1/5, batch: 37376
# Época: 1/5, batch: 37888
# Época: 1/5, batch: 38400
# Época: 1/5, batch: 38912
# Época: 1/5, batch: 39424
# Época: 1/5, batch: 39936
# Época: 1/5, batch: 40448
# Época: 1/5, batch: 40960
# Época: 1/5, batch: 41472
# Época: 1/5, batch: 41984
# Época: 1/5, batch: 42496
# Época: 1/5, batch: 43008
# Época: 1/5, batch: 43520
# Época: 1/5, batch: 44032
# Época: 1/5, batch: 44544
# Época: 1/5, batch: 45056
# Época: 1/5, batch: 45568
# Época: 1/5, batch: 46080
# Época: 1/5, batch: 46592
# Época: 1/5, batch: 47104
# Época: 1/5, batch: 47616
# Época: 1/5, batch: 48128
# Época: 1/5, batch: 48640
# Época: 1/5, batch: 49152
# Época: 1/5, batch: 49664
# Época: 1/5, batch: 50176
# Época: 1/5, batch: 50688
# Época: 1/5, batch: 51200
# Época: 1/5, batch: 51712
# Época: 1/5, batch: 52224
# Época: 1/5, batch: 52736
# Época: 1/5, batch: 53248
# Época: 1/5, batch: 53760
# Época: 1/5, batch: 54272
# Época: 1/5, batch: 54784
# Época: 1/5, batch: 55296
# Época: 1/5, batch: 55808
# Época: 1/5, batch: 56320
# Época: 1/5, batch: 56832
# Época: 1/5, batch: 57344
# Época: 1/5, batch: 57856
# Época: 1/5, batch: 58368
# Época: 1/5, batch: 58880
# Época: 1/5, batch: 59392
# Época: 1/5, batch: 59904
# Época: 1/5, batch: 60416
# Época: 1/5, batch: 60928
# Época: 1/5, batch: 61440
# Época: 1/5, batch: 61952
# Época: 1/5, batch: 62464
# Época: 1/5, batch: 62976
# Época: 1/5, batch: 63488
# Época: 1/5, batch: 64000
# Época: 1/5, batch: 64512
# Época: 1/5, batch: 65024
# Época: 1/5, batch: 65536
# Época: 1/5, batch: 66048
# Época: 1/5, batch: 66560
# Época: 1/5, batch: 67072
# Época: 1/5, batch: 67584
# Época: 1/5, batch: 68096
# Época: 1/5, batch: 68608
# Época: 1/5, batch: 69120
# Época: 1/5, batch: 69632
# Época: 1/5, batch: 70144
# Época: 1/5, batch: 70656
# Época: 1/5, batch: 71168
# Época: 1/5, batch: 71680
# Época: 1/5, batch: 72192
# Época: 1/5, batch: 72704
# Época: 1/5, batch: 73216
# Época: 1/5, batch: 73728
# Época: 1/5, batch: 74240
# Época: 1/5, batch: 74752
# Época: 1/5, batch: 75264
# Época: 1/5, batch: 75776
# Época: 1/5, batch: 76288
# Época: 1/5, batch: 76800
# Época: 1/5, batch: 77312
# Época: 1/5, batch: 77824
# Época: 1/5, batch: 78336
# Época: 1/5, batch: 78848
# Época: 1/5, batch: 79360
# Época: 1/5, batch: 79872
# Época: 1/5, batch: 80384
# Época: 1/5, batch: 80896
# Época: 1/5, batch: 81408
# Época: 1/5, batch: 81920
# Época: 1/5, batch: 82432
# Época: 1/5, batch: 82944
# Época: 1/5, batch: 83456
# Época: 1/5, batch: 83968
# Época: 1/5, batch: 84480
# Época: 1/5, batch: 84992
# Época: 1/5, batch: 85504
# Época: 1/5, batch: 86016
# Época: 1/5, batch: 86528
# Época: 1/5, batch: 87040
# Época: 1/5, batch: 87552
# Época: 1/5, batch: 88064
# Época: 1/5, batch: 88576
# Época: 1/5, batch: 89088
# Época: 1/5, batch: 89600
# Época: 1/5, batch: 90112
# Época: 1/5, batch: 90624
# Época: 1/5, batch: 91136
# Época: 1/5, batch: 91648
# Época: 1/5, batch: 92160
# Época: 1/5, batch: 92672
# Época: 1/5, batch: 93184
# Época: 1/5, batch: 93696
# Época: 1/5, batch: 94208
# Época: 1/5, batch: 94720
# Época: 1/5, batch: 95232
# Época: 1/5, batch: 95744
# Época: 1/5, batch: 96256
# Época: 1/5, batch: 96768
# Época: 1/5, batch: 97280
# Época: 1/5, batch: 97792
# Época: 1/5, batch: 98304
# Época: 1/5, batch: 98816
# Época: 1/5, batch: 99328
# Época: 1/5, batch: 99840
# Época: 1/5, batch: 100352
# Época: 1/5, batch: 100864
# Época: 1/5, batch: 101376
# Época: 1/5, batch: 101888
# Época: 1/5, batch: 102400
# Época: 1/5, batch: 102912
# Época: 1/5, batch: 103424
# Época: 1/5, batch: 103936
# Época: 1/5, batch: 104448
# Época: 1/5, batch: 104960
# Época: 1/5, batch: 105472
# Época: 1/5, batch: 105984
# Época: 1/5, batch: 106496
# Época: 1/5, batch: 107008
# Época: 1/5, batch: 107520
# Época: 1/5, batch: 108032
# Época: 1/5, batch: 108544
# Época: 1/5, batch: 109056
# Época: 1/5, batch: 109568
# Época: 1/5, batch: 110080
# Época: 1/5, batch: 110592
# Época: 1/5, batch: 111104
# Época: 1/5, batch: 111616
# Época: 1/5, batch: 112128
# Época: 1/5, batch: 112640
# Época: 1/5, batch: 113152
# Época: 1/5, batch: 113664
# Época: 1/5, batch: 114176
# Época: 1/5, batch: 114688
# Época: 1/5, batch: 115200
# Época: 1/5, batch: 115712
# Época: 1/5, batch: 116224
# Época: 1/5, batch: 116736
# Época: 1/5, batch: 117248
# Época: 1/5, batch: 117760
# Época: 1/5, batch: 118272
# Época: 1/5, batch: 118784
# Época: 1/5, batch: 119296
# Época: 1/5, batch: 119808
# Época: 1/5, batch: 120320
# Época: 1/5, batch: 120832
# Época: 1/5, batch: 121344
# Época: 1/5, batch: 121856
# Época: 1/5, batch: 122368
# Época: 1/5, batch: 122880
# Época: 1/5, batch: 123392
# Época: 1/5, batch: 123904
# Época: 1/5, batch: 124416
# Época: 1/5, batch: 124928
# Época: 1/5, batch: 125440
# Época: 1/5, batch: 125952
# Época: 1/5, batch: 126464
# Época: 1/5, batch: 126976
# Época: 1/5, batch: 127488
# Época: 1/5, batch: 128000
# Época: 1/5, batch: 128512
# Época: 1/5, batch: 129024
# Época: 1/5, batch: 129536
# Época: 1/5, batch: 130048
# Época: 1/5, batch: 130560
# Época: 1/5, batch: 131072
# Época: 1/5, batch: 131584
# Época: 1/5, batch: 132096
# Época: 1/5, batch: 132608
# Época: 1/5, batch: 133120
# Época: 1/5, batch: 133632
# Época: 1/5, batch: 134144
# Época: 1/5, batch: 134656
# Época: 1/5, batch: 135168
# Época: 1/5, batch: 135680
# Época: 1/5, batch: 136192
# Época: 1/5, batch: 136704
# Época: 1/5, batch: 137216
# Época: 1/5, batch: 137728
# Época: 1/5, batch: 138240
# Época: 1/5, batch: 138752
# Época: 1/5, batch: 139264
# Época: 1/5, batch: 139776
# Época: 1/5, batch: 140288
# Época: 1/5, batch: 140800
# Época: 1/5, batch: 141312
# Época: 1/5, batch: 141824
# Época: 1/5, batch: 142336
# Época: 1/5, batch: 142848
# Época: 1/5, batch: 143360
# Época: 1/5, batch: 143872
# Época: 1/5, batch: 144384
# Época: 1/5, batch: 144896
# Época: 1/5, batch: 145408
# Época: 1/5, batch: 145920
# Época: 1/5, batch: 146432
# Época: 1/5, batch: 146944
# Época: 1/5, batch: 147456
# Época: 1/5, batch: 147968
# Época: 1/5, batch: 148480
# Época: 1/5, batch: 148992
# Época: 1/5, batch: 149504
# Época: 1/5, batch: 150016
# Época: 1/5, batch: 150528
# Época: 1/5, batch: 151040
# Época: 1/5, batch: 151552
# Época: 1/5, batch: 152064
# Época: 1/5, batch: 152576
# Época: 1/5, batch: 153088
# Época: 1/5, batch: 153600
# Época: 1/5, batch: 154112
# Época: 1/5, batch: 154624
# Época: 1/5, batch: 155136
# Época: 1/5, batch: 155648
# Época: 1/5, batch: 156160
# Época: 1/5, batch: 156672
# Época: 1/5, batch: 157184
# Época: 1/5, batch: 157696
# Época: 1/5, batch: 158208
# Época: 1/5, batch: 158720
# Época: 1/5, batch: 159232
# Época: 1/5, batch: 159744
# Época: 1/5, batch: 160256
# Época: 1/5, batch: 160768
# Época: 1/5, batch: 161280
# Época: 1/5, batch: 161792
# Época: 1/5, batch: 162304
# Época: 1/5, batch: 162816
# Época: 1/5, batch: 163328
# Época: 1/5, batch: 163840
# Época: 1/5, batch: 164352
# Época: 1/5, batch: 164864
# Época: 1/5, batch: 165376
# Época: 1/5, batch: 165888
# Época: 1/5, batch: 166400
# Época: 1/5, batch: 166912
# Época: 1/5, batch: 167424
# Época: 1/5, batch: 167936
# Época: 1/5, batch: 168448
# Época: 1/5, batch: 168960
# Época: 1/5, batch: 169472
# Época: 1/5, batch: 169984
# Época: 1/5, batch: 170496
# Época: 1/5, batch: 171008
# Época: 1/5, batch: 171520
# Época: 1/5, batch: 172032
# Época: 1/5, batch: 172544
# Época: 1/5, batch: 173056
# Época: 1/5, batch: 173568
# Época: 1/5, batch: 174080
# Época: 1/5, batch: 174592
# Época: 1/5, batch: 175104
# Época: 1/5, batch: 175616
# Época: 1/5, batch: 176128
# Época: 1/5, batch: 176640
# Época: 1/5, batch: 177152
# Época: 1/5, batch: 177664
# Época: 1/5, batch: 178176
# Época: 1/5, batch: 178688
# Época: 1/5, batch: 179200
# Época: 1/5, batch: 179712
# Época: 1/5, batch: 180224
# Época: 1/5, batch: 180736
# Época: 1/5, batch: 181248
# Época: 1/5, batch: 181760
# Época: 1/5, batch: 182272
# Época: 1/5, batch: 182784
# Época: 1/5, batch: 183296
# Época: 1/5, batch: 183808
# Época: 1/5, batch: 184320
# Época: 1/5, batch: 184832
# Época: 1/5, batch: 185344
# Época: 1/5, batch: 185856
# Época: 1/5, batch: 186368
# Época: 1/5, batch: 186880
# Época: 1/5, batch: 187392
# Época: 1/5, batch: 187904
# Época: 1/5, batch: 188416
# Época: 1/5, batch: 188928
# Época: 1/5, batch: 189440
# Época: 1/5, batch: 189952
# Época: 1/5, batch: 190464
# Época: 1/5, batch: 190976
# Época: 1/5, batch: 191488
# Época: 1/5, batch: 192000
# Época: 1/5, batch: 192512
# Época: 1/5, batch: 193024
# Época: 1/5, batch: 193536
# Época: 1/5, batch: 194048
# Época: 1/5, batch: 194560
# Época: 1/5, batch: 195072
# Época: 1/5, batch: 195584
# Época: 1/5, batch: 196096
# Época: 1/5, batch: 196608
# Época: 1/5, batch: 197120
# Época: 1/5, batch: 197632
# Época: 1/5, batch: 198144
# Época: 1/5, batch: 198656
# Época: 1/5, batch: 199168
# Época: 1/5, batch: 199680
# Época: 1/5, batch: 200192
# Época: 1/5, batch: 200704
# Época: 1/5, batch: 201216
# Época: 1/5, batch: 201728
# Época: 1/5, batch: 202240
# Época: 1/5, batch: 202752
# Época: 1/5, batch: 203264
# Época: 1/5, batch: 203776
# Época: 1/5, batch: 204288
# Época: 1/5, batch: 204800
# Época: 1/5, batch: 205312
# Época: 1/5, batch: 205824
# Época: 1/5, batch: 206336
# Época: 1/5, batch: 206848
# Época: 1/5, batch: 207360
# Época: 1/5, batch: 207872
# Época: 1/5, batch: 208384
# Época: 1/5, batch: 208896
# Época: 1/5, batch: 209408
# Época: 1/5, batch: 209920
# Época: 1/5, batch: 210432
# Época: 1/5, batch: 210944
# Época: 1/5, batch: 211456
# Época: 1/5, batch: 211968
# Época: 1/5, batch: 212480
# Época: 1/5, batch: 212992
# Época: 1/5, batch: 213504
# Época: 1/5, batch: 214016
# Época: 1/5, batch: 214528
# Época: 1/5, batch: 215040
# Época: 1/5, batch: 215552
# Época: 1/5, batch: 216064
# Época: 1/5, batch: 216576
# Época: 1/5, batch: 217088
# Época: 1/5, batch: 217600
# Época: 1/5, batch: 218112
# Época: 1/5, batch: 218624
# Época: 1/5, batch: 219136
# Época: 1/5, batch: 219648
# Época: 1/5, batch: 220160
# Época: 1/5, batch: 220672
# Época: 1/5, batch: 221184
# Época: 1/5, batch: 221696
# Época: 1/5, batch: 222208
# Época: 1/5, batch: 222720
# Época: 1/5, batch: 223232
# Época: 1/5, batch: 223744
# Época: 1/5, batch: 224256
# Época: 1/5, batch: 224768
# Época: 1/5, batch: 225280
# Época: 1/5, batch: 225792
# Época: 1/5, batch: 226304
# Época: 1/5, batch: 226816
# Época: 1/5, batch: 227328
# Época: 1/5, batch: 227840
# Época: 1/5, batch: 228352
# Época: 1/5, batch: 228864
# Época: 1/5, batch: 229376
# Época: 1/5, batch: 229888
# Época: 1/5, batch: 230400
# Época: 1/5, batch: 230912
# Época: 1/5, batch: 231424
# Época: 1/5, batch: 231936
# Época: 1/5, batch: 232448
# Época: 1/5, batch: 232960
# Época: 1/5, batch: 233472
# Época: 1/5, batch: 233984
# Época: 1/5, batch: 234496
# Época: 1/5, batch: 235008
# Época: 1/5, batch: 235520
# Época: 1/5, batch: 236032
# Época: 1/5, batch: 236544
# Época: 1/5, batch: 237056
# Época: 1/5, batch: 237568
# Época: 1/5, batch: 238080
# Época: 1/5, batch: 238592
# Época: 1/5, batch: 239104
# Época: 1/5, batch: 239616
# Época: 1/5, batch: 240128
# Época: 1/5, batch: 240640
# Época: 1/5, batch: 241152
# Época: 1/5, batch: 241664
# Época: 1/5, batch: 242176
# Época: 1/5, batch: 242688
# Época: 1/5, batch: 243200
# Época: 1/5, batch: 243712
# Época: 1/5, batch: 244224
# Época: 1/5, batch: 244736
# Época: 1/5, batch: 245248
# Época: 1/5, batch: 245760
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6869/3418650125.py in <cell line: 0>()
#      41
#      42     with torch.no_grad():
# ---> 43         for x_val, y_val in loader_val:
#      44             inputs_val = Variable(x_val.view(-1, 28 * 28))
#      45             labels_val = Variable(y_val)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     799     def _next_data(self):
#     800         index = self._next_index()  # may raise StopIteration
# --> 801         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802         if self._pin_memory:
#     803             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         if self.auto_collation:
#      51             if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52                 data = self.dataset.__getitems__(possibly_batched_index)
#      53             else:
#      54                 data = [self.dataset[idx] for idx in possibly_batched_index]
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataset.py in __getitems__(self, indices)
#     411             return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     412         else:
# --> 413             return [self.dataset[self.indices[idx]] for idx in indices]
#     414
#     415     def __len__(self) -> int:
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     137             tuple: (image, target) where target is index of the target class.
#     138         """
# --> 139         img, target = self.data[index], int(self.targets[index])
#     140
#     141         # doing this so that it is consistent with all other datasets
#
# KeyboardInterrupt:

# %%
batch_size = 32    # 1ª rodada
batch_size = 100   # 2ª rodada (padrão)
batch_size = 512   # 3ª rodada

# %% [markdown]
# ## Conclusões sobre os experimentos deste notebook
